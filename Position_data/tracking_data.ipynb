# %%
import sys
sys.path.append('C:\\Users\\DavidB\\PycharmProjects\\My_Football_Analytics')

import pandas as pd
import numpy as np
import Basics.Data.Metrica_IO as mio
from Position_data.Tracking_Data import tracking_data
from mplsoccer import Pitch
import matplotlib.pyplot as plt
from Basics.Data.DFL_data import parse_dfl_pos_data

# %% [markdown]
# ## metrica data

# %%
data_dir = 'PitchControl/sample-data-master/data/'
game_id = 2
away = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Away')
home = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Home')
td = mio.merge_tracking_data(home, away)
td
# Out:
# Reading team: away
# Reading team: home
#         Period  Time [s]  Home_11_x  Home_11_y  Home_1_x  Home_1_y  Home_2_x  \
# Frame
# 1            1      0.04    0.94275    0.50413   0.64812   0.28605   0.67752
# 2            1      0.08    0.94275    0.50413   0.64812   0.28605   0.67752
# 3            1      0.12    0.94275    0.50413   0.64812   0.28605   0.67752
# 4            1      0.16    0.94275    0.50413   0.64812   0.28605   0.67752
# 5            1      0.20    0.94275    0.50413   0.64812   0.28605   0.67752
# ...        ...       ...        ...        ...       ...       ...       ...
# 141152       2   5646.08    0.06285    0.51243   0.38499   0.15356   0.22558
# 141153       2   5646.12    0.06285    0.51243   0.38499   0.15356   0.22558
# 141154       2   5646.16    0.06285    0.51243   0.38499   0.15356   0.22558
# 141155       2   5646.20    0.06285    0.51243   0.38499   0.15356   0.22558
# ...

# %%
td_object = tracking_data(td, data_source='metrica', scale_to_pitch='myPitch')
print(td_object)
# Out:
# tracking_data object of metrica of shape (141156, 56).

# %%
td_object.get_velocities()
td_object.data.head()
# Out:
#        Period  Time [s]  Home_11_x  Home_11_y  Home_1_x  Home_1_y  Home_2_x  \
# Frame
# 1           1      0.04   98.98875   32.23155   68.0526  46.40675   71.1396
# 2           1      0.08   98.98875   32.23155   68.0526  46.40675   71.1396
# 3           1      0.12   98.98875   32.23155   68.0526  46.40675   71.1396
# 4           1      0.16   98.98875   32.23155   68.0526  46.40675   71.1396
# 5           1      0.20   98.98875   32.23155   68.0526  46.40675   71.1396
#
#        Home_2_y  Home_3_x  Home_3_y  ...  Home_6_speed  Home_7_vx  Home_7_vy  \
# Frame                                ...
# 1      37.17805   73.3761   28.8561  ...           NaN        NaN        NaN
# 2      37.17805   73.3761   28.8561  ...           NaN        NaN        NaN
# 3      37.17805   73.3761   28.8561  ...           NaN        NaN        NaN
# 4      37.17805   73.3761   28.8561  ...           NaN        NaN        NaN
# ...

# %%
td_object.playing_direction_home, td_object.playing_direction_away
# Out:
# ('rtl', 'ltr')

# %%
td_object.Home_GK, td_object.Away_GK
# Out:
# ('11', '25')

# %%
td_object.plot_players(frame=340, velocities=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
td_object.animation_clip(frames=(51, 150), fname='metrica_clip', velocities=True)
# Out:
# Generating your clip...done

# %% [markdown]
# ## DFL data

# %%
pos_filepath = 'DFL_04_02_positions_raw_DFL-COM-000001_DFL-MAT-0027AD.xml'
mi_filepath = 'DFL_02_01_matchinformation_DFL-COM-000001_DFL-MAT-0027AD.xml'

td_dfl, x_range_data, y_range_data = parse_dfl_pos_data(pos_filepath=pos_filepath, mi_filepath=mi_filepath)
td_dfl
# Out:
#        ball_x ball_y ballstatus possession GameSection             Time  \
# 0       -0.38  -0.28        1.0        2.0   firstHalf  00:00:00.000000
# 1       -0.35   -0.3        1.0        2.0   firstHalf  00:00:00.040000
# 2       -0.33  -0.32        1.0        2.0   firstHalf  00:00:00.080000
# 3       -0.31  -0.33        1.0        2.0   firstHalf  00:00:00.120000
# 4        1.09  -0.13        1.0        2.0   firstHalf  00:00:00.160000
# ...       ...    ...        ...        ...         ...              ...
# 137214  23.04   6.63        0.0        2.0  secondHalf  01:31:17.360000
# 137215  23.02   6.62        0.0        2.0  secondHalf  01:31:17.400000
# 137216  23.01   6.62        0.0        2.0  secondHalf  01:31:17.440000
# 137217   23.0   6.61        0.0        2.0  secondHalf  01:31:17.480000
# 137218  22.98    6.6        0.0        2.0  secondHalf  01:31:17.520000
#
#        Time [s] Home_30_x Home_30_y Home_27_x  ... Away_15_y Away_5_x  \
# ...

# %%
td_object_dfl = tracking_data(td_dfl, data_source='dfl', scale_to_pitch='mplsoccer',
                              x_range_data=x_range_data, y_range_data=y_range_data)
print(td_object_dfl)
# Out:
# tracking_data object of dfl of shape (137219, 64).

# %%
td_object_dfl.get_velocities()
td_object_dfl.data.head()
# Out:
#    ball_x     ball_y ballstatus possession GameSection             Time  \
# 0  59.544  40.329412        1.0        2.0   firstHalf  00:00:00.000000
# 1   59.58  40.352941        1.0        2.0   firstHalf  00:00:00.040000
# 2  59.604  40.376471        1.0        2.0   firstHalf  00:00:00.080000
# 3  59.628  40.388235        1.0        2.0   firstHalf  00:00:00.120000
# 4  61.308  40.152941        1.0        2.0   firstHalf  00:00:00.160000
#
#   Time [s] Home_30_x  Home_30_y Home_27_x  ... Home_4_speed     Home_6_vx  \
# 0        0    40.932  18.047059     48.36  ...          NaN           NaN
# 1     0.04    40.932  18.047059    48.348  ...          NaN           NaN
# 2     0.08    40.932  18.047059    48.324  ...          NaN           NaN
# 3     0.12    40.932  18.047059      48.3  ...          NaN           NaN
# 4     0.16    40.944  18.047059    48.276  ...     0.697204 -2.081668e-17
#
#   Home_6_vy Home_6_speed Home_7_vx Home_7_vy Home_7_speed Home_8_vx Home_8_vy  \
# ...

# %%
td_object_dfl.playing_direction_home, td_object_dfl.playing_direction_away
# Out:
# ('ltr', 'rtl')

# %%
td_object_dfl.Home_GK, td_object_dfl.Away_GK
# Out:
# ('1', '1')

# %%
td_object_dfl.plot_players(frame=10, velocities=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
td_object_dfl.animation_clip(frames=(51, 150), fname='dfl_clip', velocities=True)
# Out:
# Generating your clip...done

# %% [markdown]
# # Pitch range different from pitch type's standard dimensions

# %% [markdown]
# ## no problem with myPitch

# %%
td_object_dfl = tracking_data(td_dfl, data_source='dfl', scale_to_pitch='myPitch',
                              x_range_data=x_range_data, y_range_data=y_range_data,
                             x_range_pitch=(-50, 50), y_range_pitch=(60, 0))
print(td_object_dfl)
# Out:
# tracking_data object of dfl of shape (137219, 64).

# %%
td_object_dfl.get_velocities()
td_object_dfl.data.head()
# Out:
#   ball_x     ball_y ballstatus possession GameSection             Time  \
# 0  -0.38  30.247059        1.0        2.0   firstHalf  00:00:00.000000
# 1  -0.35  30.264706        1.0        2.0   firstHalf  00:00:00.040000
# 2  -0.33  30.282353        1.0        2.0   firstHalf  00:00:00.080000
# 3  -0.31  30.291176        1.0        2.0   firstHalf  00:00:00.120000
# 4   1.09  30.114706        1.0        2.0   firstHalf  00:00:00.160000
#
#   Time [s] Home_30_x  Home_30_y Home_27_x  ... Home_4_speed     Home_6_vx  \
# 0        0    -15.89  13.535294      -9.7  ...          NaN           NaN
# 1     0.04    -15.89  13.535294     -9.71  ...          NaN           NaN
# 2     0.08    -15.89  13.535294     -9.73  ...          NaN           NaN
# 3     0.12    -15.89  13.535294     -9.75  ...          NaN           NaN
# 4     0.16    -15.88  13.535294     -9.77  ...     0.579196 -1.387779e-17
#
#   Home_6_vy Home_6_speed Home_7_vx Home_7_vy Home_7_speed Home_8_vx Home_8_vy  \
# ...

# %%
td_object_dfl.plot_players(frame=10, velocities=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## mplsoccer does not allow rescaling

# %%
td_object_dfl = tracking_data(td_dfl, data_source='dfl', scale_to_pitch='mplsoccer',
                              x_range_data=x_range_data, y_range_data=y_range_data,
                              x_range_pitch=(-50, 50), y_range_pitch=(60, 0))
# Out:
# WARNING:root:mplsoccer pitch does not allow for a rescaling of the pitch. Axis ranges remain as(0, 120) for x and (80, 0) for y!

# %%
print(td_object_dfl)
# Out:
# tracking_data object of dfl of shape (137219, 64).

# %%
td_object_dfl.plot_players(frame=10, velocities=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
td_object_dfl.dimensions
# Out:
# {'y': {'data': (-34.0, 34.0),
#   'pitch': (80, 0),
#   'home_columns': ['Home_30_y',
#    'Home_27_y',
#    'Home_8_y',
#    'Home_15_y',
#    'Home_32_y',
#    'Home_6_y',
#    'Home_4_y',
#    'Home_7_y',
#    'Home_1_y',
#    'Home_26_y',
#    'Home_3_y',
#    'Home_18_y',
#    'Home_19_y',
#    'Home_25_y'],
#   'away_columns': ['Away_7_y',
#    'Away_27_y',
#    'Away_30_y',
#    'Away_34_y',
#    'Away_22_y',
#    'Away_13_y',
#    'Away_1_y',
#    'Away_14_y',
#    'Away_33_y',
#    'Away_15_y',
#    'Away_5_y',
#    'Away_4_y',
#    'Away_11_y',
#    'Away_17_y'],
#   'ball_columns': ['ball_y'],
#   'delta_data': 68.0,
#   'delta_pitch': -80,
#   'scaling_factor': -1.1764705882352942},
#  'x': {'data': (-50.0, 50.0),
#   'pitch': (0, 120),
#   'home_columns': ['Home_30_x',
#    'Home_27_x',
#    'Home_8_x',
#    'Home_15_x',
#    'Home_32_x',
#    'Home_6_x',
#    'Home_4_x',
#    'Home_7_x',
#    'Home_1_x',
#    'Home_26_x',
#    'Home_3_x',
#    'Home_18_x',
# ...
