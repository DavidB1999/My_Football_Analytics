# %%
import sys
sys.path.append('C:\\Users\\DavidB\\PycharmProjects\\My_Football_Analytics\\Basics')

import pandas as pd
import numpy as np
import Data.Metrica_IO as mio
from Tracking_Data import tracking_data

# %%
data_dir = 'PitchControl/sample-data-master/data/'
game_id = 2
away = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Away')
home = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Home')
td = mio.merge_tracking_data(home, away)
td
# Out:
# Reading team: away
# Reading team: home
#         Period_x  Time [s]_x  Home_11_x  Home_11_y  Home_1_x  Home_1_y  \
# Frame
# 1              1        0.04    0.94275    0.50413   0.64812   0.28605
# 2              1        0.08    0.94275    0.50413   0.64812   0.28605
# 3              1        0.12    0.94275    0.50413   0.64812   0.28605
# 4              1        0.16    0.94275    0.50413   0.64812   0.28605
# 5              1        0.20    0.94275    0.50413   0.64812   0.28605
# ...          ...         ...        ...        ...       ...       ...
# 141152         2     5646.08    0.06285    0.51243   0.38499   0.15356
# 141153         2     5646.12    0.06285    0.51243   0.38499   0.15356
# 141154         2     5646.16    0.06285    0.51243   0.38499   0.15356
# 141155         2     5646.20    0.06285    0.51243   0.38499   0.15356
# 141156         2     5646.24    0.06285    0.51243   0.38499   0.15356
#
#         Home_2_x  Home_2_y  Home_3_x  Home_3_y  ...  Away_22_x  Away_22_y  \
# Frame                                           ...
# 1        0.67752   0.42803   0.69882   0.55606  ...    0.49889   -0.02263
# 2        0.67752   0.42803   0.69882   0.55606  ...    0.49889   -0.02263
# 3        0.67752   0.42803   0.69882   0.55606  ...    0.49889   -0.02263
# 4        0.67752   0.42803   0.69882   0.55606  ...    0.49889   -0.02263
# 5        0.67752   0.42803   0.69882   0.55606  ...    0.49889   -0.02263
# ...          ...       ...       ...       ...  ...        ...        ...
# 141152   0.22558   0.41355   0.27142   0.32209  ...        NaN        NaN
# 141153   0.22558   0.41355   0.27142   0.32209  ...        NaN        NaN
# 141154   0.22558   0.41355   0.27142   0.32209  ...        NaN        NaN
# 141155   0.22558   0.41355   0.27142   0.32209  ...        NaN        NaN
# 141156   0.22558   0.41355   0.27142   0.32209  ...        NaN        NaN
#
#         Away_23_x  Away_23_y  Away_24_x  Away_24_y  Away_26_x  Away_26_y  \
# Frame
# 1         0.50177    0.50145    0.49517    0.36234        NaN        NaN
# 2         0.50177    0.50145    0.49517    0.36234        NaN        NaN
# 3         0.50177    0.50145    0.49517    0.36234        NaN        NaN
# 4         0.50177    0.50145    0.49517    0.36234        NaN        NaN
# 5         0.50177    0.50145    0.49517    0.36234        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 141152    0.26855    0.61845    0.36760    0.12496    0.44966    0.41572
# 141153    0.26855    0.61845    0.36760    0.12496    0.44983    0.41550
# 141154    0.26855    0.61845    0.36760    0.12496    0.44997    0.41485
# 141155    0.26855    0.61845    0.36760    0.12496    0.45017    0.41515
# 141156    0.26855    0.61845    0.36760    0.12496    0.45029    0.41545
#
#         ball_x  ball_y
# Frame
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# 5          NaN     NaN
# ...        ...     ...
# 141152     NaN     NaN
# 141153     NaN     NaN
# 141154     NaN     NaN
# 141155     NaN     NaN
# 141156     NaN     NaN
#
# [141156 rows x 58 columns]

# %%
td_object = tracking_data(td, data_source='metrica', scale_to_pitch='mplsoccer')
print(td_object)
# Out:
# tracking_data object of metrica of shape (141156, 58).

# %%
td_object.plot_players(frame=51)
