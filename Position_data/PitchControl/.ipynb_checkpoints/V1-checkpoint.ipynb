# %% [markdown]
# https://www.youtube.com/watch?v=8TrleFklEsE

# %%
import sys
sys.path.append('C:\\Users\\DavidB\\PycharmProjects\\My_Football_Analytics\\Basics')

import pandas as pd
import numpy as np
import Data.Metrica_IO as mio

# %%
data_dir = 'sample-data-master/data/'
game_id = 2
td = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Away')
td
# Out:
# Reading team: away
#         Period  Time [s]  Away_25_x  Away_25_y  Away_15_x  Away_15_y  \
# Frame
# 1            1      0.04    0.01218    0.51763    0.32891    0.81846
# 2            1      0.08    0.01218    0.51763    0.32891    0.81846
# 3            1      0.12    0.01218    0.51763    0.32891    0.81846
# 4            1      0.16    0.01218    0.51763    0.32836    0.81847
# 5            1      0.20    0.01218    0.51763    0.32783    0.81847
# ...        ...       ...        ...        ...        ...        ...
# 141152       2   5646.08    0.91211    0.48311    0.49028   -0.05000
# 141153       2   5646.12    0.91191    0.48311    0.49028   -0.05000
# 141154       2   5646.16    0.91168    0.48311    0.49028   -0.05000
# 141155       2   5646.20    0.91151    0.48311    0.49028   -0.05000
# 141156       2   5646.24    0.91116    0.48312    0.49028   -0.05000
#
#         Away_16_x  Away_16_y  Away_17_x  Away_17_y  ...  Away_22_x  Away_22_y  \
# ...

# %%
td_new = mio.to_metric_coordinates(td, origin='bottom_left', in_place=False, field_dimen=(120, 80))
td_new
# Out:
#         Period  Time [s]  Away_25_x  Away_25_y  Away_15_x  Away_15_y  \
# Frame
# 1            1      0.04    1.29108   32.80116   34.86446   12.34472
# 2            1      0.08    1.29108   32.80116   34.86446   12.34472
# 3            1      0.12    1.29108   32.80116   34.86446   12.34472
# 4            1      0.16    1.29108   32.80116   34.80616   12.34404
# 5            1      0.20    1.29108   32.80116   34.74998   12.34404
# ...        ...       ...        ...        ...        ...        ...
# 141152       2   5646.08   96.68366   35.14852   51.96968   71.40000
# 141153       2   5646.12   96.66246   35.14852   51.96968   71.40000
# 141154       2   5646.16   96.63808   35.14852   51.96968   71.40000
# 141155       2   5646.20   96.62006   35.14852   51.96968   71.40000
# 141156       2   5646.24   96.58296   35.14784   51.96968   71.40000
#
#         Away_16_x  Away_16_y  Away_17_x  Away_17_y  ...  Away_22_x  Away_22_y  \
# ...
