# %%
import sys
sys.path.append('C:\\Users\\DavidB\\PycharmProjects\\My_Football_Analytics')

from Position_data.Tracking_Data import tracking_data  
from Basics.Pitch.My_Pitch import myPitch
from mplsoccer import Pitch
import Basics.Data.Metrica_IO as mio
from Position_data.PitchControl import pitch_control

# %%
# supposed to be based on td_object --> first create one
# everywhere we call the object now will later be self

data_dir = 'Position_data/PitchControl/sample-data-master/data/'
game_id = 1
away = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Away')
home = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Home')
td = mio.merge_tracking_data(home, away)
td_object = tracking_data(td, data_source='metrica', scale_to_pitch='mplsoccer')
td_object.get_velocities()

td_object
# Out:
# Reading team: away
# Reading team: home

# %%
pitch_control.plot_tensor_pitch_control(td_object=td_object, version='Fernandez',  first_frame=0, last_frame=250,
                                        frame=100, implementation='adap')
# Out:
# Modelling pitch control...
# Current batch: 1/1

# %%
pitch_control.plot_tensor_pitch_control(td_object=td_object, version='Fernandez',  first_frame=0, last_frame=400,
                                        frame=350, implementation='adap')
# Out:
# Modelling pitch control...
# Current batch: 1/2
# Current batch: 2/2

# %%
pitch_control.animate_tensor_pitch_control(td_object=td_object, version='Spearman', first_frame_ani=200, last_frame_ani=300,
                                          first_frame_calc=0, last_frame_calc=400)
# Out:
# Running Spearman's pitch control computation based on Gauss legendre quadration
# Current batch: 1/2
# Current batch: 2/2
# Generating your clip...
# 25.0% done!
# 50.0% done!
# 75.0% done!
# All done!

# %%
pitch_control.plot_tensor_pitch_control(td_object, version='Spearman', frame=200, first_frame=0, last_frame=250)
# Out:
# Modelling pitch control...
# Running Spearman's pitch control computation based on Gauss legendre quadration
# Current batch: 1/1

# %%
pitch_control.plot_tensor_pitch_control(td_object, version='Spearman', frame=201, first_frame=0, last_frame=250)
# Out:
# Modelling pitch control...
# Running Spearman's pitch control computation based on Gauss legendre quadration
# Current batch: 1/1
