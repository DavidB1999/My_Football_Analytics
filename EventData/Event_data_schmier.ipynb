# %%
import pandas as pd
import numpy as np
from EventData import event_data

# %%
def load_event_data(datadir, fname):

    eventfile = datadir + '/' + fname
    print(eventfile)
    events = pd.read_csv(eventfile) # read data
    return events

# %%
ed = load_event_data('sample-data-master/data/Sample_Game_2', 'Sample_Game_2_RawEventsData.csv')
ed
# Out:
# sample-data-master/data/Sample_Game_2/Sample_Game_2_RawEventsData.csv
#       Team       Type       Subtype  Period  Start Frame  Start Time [s]  \
# 0     Away  SET PIECE      KICK OFF       1           51            2.04
# 1     Away       PASS           NaN       1           51            2.04
# 2     Away       PASS           NaN       1          146            5.84
# 3     Away       PASS           NaN       1          248            9.92
# 4     Away       PASS           NaN       1          316           12.64
# ...    ...        ...           ...     ...          ...             ...
# 1930  Away  BALL LOST  INTERCEPTION       2       140122         5604.88
# 1931  Home  CHALLENGE   AERIAL-LOST       2       140180         5607.20
# 1932  Away  CHALLENGE   AERIAL-LOST       2       140183         5607.32
# 1933  Home   RECOVERY           NaN       2       140211         5608.44
# 1934  Home   BALL OUT     CLEARANCE       2       140265         5610.60
#
# ...

# %%
ED = event_data(data=ed, data_source='metrica', mirror_second_half=True)

# %%
print(ED)
ED.dimensions
# Out:
# event_data object with data from metrica
# {'x': {'data': (0, 1),
#   'pitch': (0, 105),
#   'delta_data': 1,
#   'delta_pitch': 105,
#   'scaling_factor': 105.0},
#  'y': {'data': (1, 0),
#   'pitch': (0, 68),
#   'delta_data': -1,
#   'delta_pitch': 68,
#   'scaling_factor': -68.0}}

# %%
ED.data
# Out:
#       Team       Type       Subtype  Period  Start_Frame  Start_Time_[s]  \
# 0     Away  SET PIECE      KICK OFF       1           51            2.04
# 1     Away       PASS           NaN       1           51            2.04
# 2     Away       PASS           NaN       1          146            5.84
# 3     Away       PASS           NaN       1          248            9.92
# 4     Away       PASS           NaN       1          316           12.64
# ...    ...        ...           ...     ...          ...             ...
# 1930  Away  BALL LOST  INTERCEPTION       2       140122         5604.88
# 1931  Home  CHALLENGE   AERIAL-LOST       2       140180         5607.20
# 1932  Away  CHALLENGE   AERIAL-LOST       2       140183         5607.32
# 1933  Home   RECOVERY           NaN       2       140211         5608.44
# 1934  Home   BALL OUT     CLEARANCE       2       140265         5610.60
#
#       End_Frame  End_Time_[s]    Player  Receiver  Start_x  Start_y  End_x  \
# ...

# %%
ED.get_event_by_type('SHOT')
# Out:
#       Team  Type              Subtype  Period  Start_Frame  Start_Time_[s]  \
# 83    Home  SHOT       OFF TARGET-OUT       1         4419          176.76
# 198   Home  SHOT       ON TARGET-GOAL       1        12202          488.08
# 252   Home  SHOT      ON TARGET-SAVED       1        16484          659.36
# 297   Away  SHOT              BLOCKED       1        18515          740.60
# 431   Home  SHOT  HEAD-OFF TARGET-OUT       1        27345         1093.80
# 472   Home  SHOT      ON TARGET-SAVED       1        29754         1190.16
# 823   Away  SHOT       ON TARGET-GOAL       1        53049         2121.96
# 852   Home  SHOT  HEAD-OFF TARGET-OUT       1        56079         2243.16
# 962   Away  SHOT  OFF TARGET-HEAD-OUT       1        63362         2534.48
# 980   Away  SHOT      ON TARGET-SAVED       1        64772         2590.88
# 1026  Home  SHOT       OFF TARGET-OUT       1        67067         2682.68
# ...

# %%
ED.data.iloc[1334]
# Out:
# Team                  Away
# Type                  PASS
# Subtype                NaN
# Period                   2
# Start_Frame          90135
# Start_Time_[s]      3605.4
# End_Frame            90165
# End_Time_[s]        3606.6
# Player            Player24
# Receiver          Player19
# Start_x              87.15
# Start_y              19.04
# End_x                 98.7
# End_y                22.44
# Name: 1334, dtype: object
