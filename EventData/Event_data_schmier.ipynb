# %%
import pandas as pd
import numpy as np
from EventData import event_data, load_metrica_event_data
from statsbombpy import sb

# %%
ed = load_metrica_event_data('sample-data-master/data/Sample_Game_2', 'Sample_Game_2_RawEventsData.csv')
ed
# Out:
#       Team       Type       Subtype  Period  Start Frame  Start Time [s]  \
# 0     Away  SET PIECE      KICK OFF       1           51            2.04
# 1     Away       PASS           NaN       1           51            2.04
# 2     Away       PASS           NaN       1          146            5.84
# 3     Away       PASS           NaN       1          248            9.92
# 4     Away       PASS           NaN       1          316           12.64
# ...    ...        ...           ...     ...          ...             ...
# 1930  Away  BALL LOST  INTERCEPTION       2       140122         5604.88
# 1931  Home  CHALLENGE   AERIAL-LOST       2       140180         5607.20
# 1932  Away  CHALLENGE   AERIAL-LOST       2       140183         5607.32
# 1933  Home   RECOVERY           NaN       2       140211         5608.44
# 1934  Home   BALL OUT     CLEARANCE       2       140265         5610.60
#
#       End Frame  End Time [s]      From        To  Start X  Start Y  End X  \
# ...

# %%
ED = event_data(data=ed, data_source='metrica')

# %%
print(ED)
ED.dimensions
# Out:
# event_data object with data from metrica
# {'x': {'data': (0, 1),
#   'pitch': (0, 105),
#   'delta_data': 1,
#   'delta_pitch': 105,
#   'scaling_factor': 105.0},
#  'y': {'data': (1, 0),
#   'pitch': (0, 68),
#   'delta_data': -1,
#   'delta_pitch': 68,
#   'scaling_factor': -68.0}}

# %%
ED.data
# Out:
#       Team       Type       Subtype  Period  Start_Frame  Start_Time_[s]  \
# 0     Away  SET PIECE      KICK OFF       1           51            2.04
# 1     Away       PASS           NaN       1           51            2.04
# 2     Away       PASS           NaN       1          146            5.84
# 3     Away       PASS           NaN       1          248            9.92
# 4     Away       PASS           NaN       1          316           12.64
# ...    ...        ...           ...     ...          ...             ...
# 1930  Away  BALL LOST  INTERCEPTION       2       140122         5604.88
# 1931  Home  CHALLENGE   AERIAL-LOST       2       140180         5607.20
# 1932  Away  CHALLENGE   AERIAL-LOST       2       140183         5607.32
# 1933  Home   RECOVERY           NaN       2       140211         5608.44
# 1934  Home   BALL OUT     CLEARANCE       2       140265         5610.60
#
#       End_Frame  End_Time_[s]    Player  Receiver  Start_x  Start_y  End_x  \
# ...

# %%
ED.get_event_by_type('SHOT')
# Out:
#       Team  Type              Subtype  Period  Start_Frame  Start_Time_[s]  \
# 83    Home  SHOT       OFF TARGET-OUT       1         4419          176.76
# 198   Home  SHOT       ON TARGET-GOAL       1        12202          488.08
# 252   Home  SHOT      ON TARGET-SAVED       1        16484          659.36
# 297   Away  SHOT              BLOCKED       1        18515          740.60
# 431   Home  SHOT  HEAD-OFF TARGET-OUT       1        27345         1093.80
# 472   Home  SHOT      ON TARGET-SAVED       1        29754         1190.16
# 823   Away  SHOT       ON TARGET-GOAL       1        53049         2121.96
# 852   Home  SHOT  HEAD-OFF TARGET-OUT       1        56079         2243.16
# 962   Away  SHOT  OFF TARGET-HEAD-OUT       1        63362         2534.48
# 980   Away  SHOT      ON TARGET-SAVED       1        64772         2590.88
# 1026  Home  SHOT       OFF TARGET-OUT       1        67067         2682.68
# ...

# %%
ED.data.iloc[1334]
# Out:
# Team                  Away
# Type                  PASS
# Subtype                NaN
# Period                   2
# Start_Frame          90135
# Start_Time_[s]      3605.4
# End_Frame            90165
# End_Time_[s]        3606.6
# Player            Player24
# Receiver          Player19
# Start_x              87.15
# Start_y              19.04
# End_x                 98.7
# End_y                22.44
# Name: 1334, dtype: object

# %%
sb_ed = sb.events(match_id=3857261)

# %%
SB_ED = event_data(sb_ed, data_source='Statsbomb')
# Out:
# mirror x away

# %%
SB_ED.data
# Out:
#       org_index     Team           Type  \
# 0             0    Wales    Starting XI
# 1             1  England    Starting XI
# 2             2    Wales     Half Start
# 3             3  England     Half Start
# 4             6    Wales           Pass
# ...         ...      ...            ...
# 3311       3145  England        Dribble
# 3312        986  England           Pass
# 3313       3310  England       Half End
# 3314       3311    Wales       Half End
# 3315       1933  England  Ball Receipt*
#
#                                                 Subtype   Outcome  Period  \
# 0     {'formation': 4231, 'lineup': [{'player': {'id...       NaN       1
# 1     {'formation': 433, 'lineup': [{'player': {'id'...       NaN       1
# 2                                                   NaN       NaN       1
# 3                                                   NaN       NaN       1
# 4                                                   NaN  Complete       1
# ...

# %%
SB_ED.get_event_by_type('Shot')
# Out:
#       org_index     Team  Type Subtype  Outcome  Period     Timestamp  \
# 437        3217  England  Shot     NaN    Saved       1  00:09:11.146
# 643        3218  England  Shot     NaN    Off T       1  00:14:03.641
# 731        3219  England  Shot     NaN    Off T       1  00:17:59.934
# 900        3220  England  Shot     NaN  Blocked       1  00:23:03.713
# 1317       3221  England  Shot     NaN    Off T       1  00:37:12.383
# 1343       3222    Wales  Shot     NaN  Blocked       1  00:38:12.492
# 1372       3223  England  Shot     NaN    Off T       1  00:38:38.910
# 1547       3224  England  Shot     NaN  Blocked       1  00:43:51.135
# 1701       3225  England  Shot     NaN  Blocked       1  00:47:16.169
# 1707       3226  England  Shot     NaN    Saved       1  00:47:55.540
# 1728       3227    Wales  Shot     NaN    Off T       1  00:49:36.290
# 1899       3228  England  Shot     NaN     Goal       2  00:04:17.488
# ...

# %% [markdown]
# # Plot events (only metrica)
#
# requires tracking data!

# %%
import Basics.Data.Metrica_IO as mio
from Position_data.Tracking_Data import tracking_data

data_dir = 'sample-data-master/data/'
game_id = 2
away = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Away')
home = mio.tracking_data(DATADIR=data_dir, game_id=game_id, teamname='Home')
td = mio.merge_tracking_data(home, away)
td_object = tracking_data(td, data_source='metrica', scale_to_pitch='myPitch')
print(td_object)
# Out:
# Reading team: away
# Reading team: home
# tracking_data object of metrica of shape (141156, 56).

# %%
ED.data.iloc[252]
# Out:
# Team                         Home
# Type                         SHOT
# Subtype           ON TARGET-SAVED
# Period                          1
# Start_Frame                 16484
# Start_Time_[s]             659.36
# End_Frame                   16499
# End_Time_[s]               659.96
# Player                   Player10
# Receiver                      NaN
# Start_x                     11.55
# Start_y                     45.56
# End_x                         4.2
# End_y                       34.68
# Name: 252, dtype: object

# %%
ED.plot_events(event_index=252, td_object=td_object, actions_back=2)
# Out:
# In development
