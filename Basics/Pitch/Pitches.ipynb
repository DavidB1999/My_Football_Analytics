# %%
# import necessary packages
import sys

sys.path.append('C:\\Users\\DavidB\\PycharmProjects\\My_Football_Analytics')
from floodlight.core import pitch
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
from Basics.Pitch.My_Pitch import myPitch, create_custom_Pitch

# %%
# create a pitch with floodlight
P = pitch.Pitch(xlim = (0,120), ylim = (0,68), unit = 'm', boundaries='flexible', sport='football')
fig, ax = plt.subplots()
P.plot(ax = ax)
# Out:
# <Axes: >

# %%
# mplsoccer

pitch = Pitch(pitch_color='grass', line_color='white',
              stripe=True)  # optional stripes
fig, ax = pitch.draw()

# %%
# my own pitch
pitch = myPitch()
fig, ax = plt.subplots(figsize=(10.5, 6.5))
pitch.plot_pitch(ax =ax)
# Out:
# <Axes: >

# %%
pitchcol='#164826'
pitch = myPitch(grasscol='#177013')
fig, ax = plt.subplots(figsize=(10.5, 6.5))
fig.set_facecolor(pitchcol)
pitch.plot_pitch(ax =ax)
# Out:
# <Axes: >

# %%
fig = create_custom_Pitch()
