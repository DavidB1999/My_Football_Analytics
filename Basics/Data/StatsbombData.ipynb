# %% [markdown]
# # Statsbomb data
#
# Statsbom supplies us with loads of free Data and even provides a easy way to access it via their own package for python and R! <br>
# https://github.com/statsbomb/statsbombpy <br>

# %%
from statsbombpy import sb

# %%
# filter for free data 
comps = sb.competitions()
comps = comps[~comps['match_available_360'].isnull()]
comps
# Out:
# C:\Users\DavidB\PycharmProjects\My_Football_Analytics\Football_Analytics_venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id   country_name   competition_name  \
# 26              43        106  International     FIFA World Cup
# 35              11         90          Spain            La Liga
# 62              55         43         Europe          UEFA Euro
# 64              53        106         Europe  UEFA Women's Euro
# 65              72        107  International  Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 26               male              False                       True
# 35               male              False                      False
# 62               male              False                       True
# 64             female              False                       True
# ...

# %%
# All matches in a competition
sb.matches(competition_id=43, season_id=106)
# Out:
# C:\Users\DavidB\PycharmProjects\My_Football_Analytics\Football_Analytics_venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     match_id  match_date      kick_off                     competition season  \
# 0    3857256  2022-12-02  21:00:00.000  International - FIFA World Cup   2022
# 1    3869151  2022-12-03  21:00:00.000  International - FIFA World Cup   2022
# 2    3857257  2022-11-30  17:00:00.000  International - FIFA World Cup   2022
# 3    3857258  2022-11-24  21:00:00.000  International - FIFA World Cup   2022
# 4    3857288  2022-11-26  12:00:00.000  International - FIFA World Cup   2022
# ..       ...         ...           ...                             ...    ...
# 59   3857265  2022-11-22  18:00:00.000  International - FIFA World Cup   2022
# 60   3857262  2022-12-02  17:00:00.000  International - FIFA World Cup   2022
# ...

# %%
# event data for a specific match 
events = sb.events(match_id=3857261)

events
# Out:
# C:\Users\DavidB\PycharmProjects\My_Football_Analytics\Football_Analytics_venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      50_50 ball_receipt_outcome ball_recovery_offensive  \
# 0      NaN                  NaN                     NaN
# 1      NaN                  NaN                     NaN
# 2      NaN                  NaN                     NaN
# 3      NaN                  NaN                     NaN
# 4      NaN                  NaN                     NaN
# ...    ...                  ...                     ...
# 3311   NaN                  NaN                     NaN
# 3312   NaN                  NaN                     NaN
# 3313   NaN                  NaN                     NaN
# 3314   NaN                  NaN                     NaN
# 3315   NaN                  NaN                     NaN
#
#      ball_recovery_recovery_failure block_deflection carry_end_location  \
# ...

# %%
# one event type
passes = sb.events(match_id=3857261, split=True, flatten_attrs=False)["passes"]
passes
# Out:
# C:\Users\DavidB\PycharmProjects\My_Football_Analytics\Football_Analytics_venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#                                        id  index  period     timestamp  \
# 0    285b3d0e-ed65-4f11-84ee-1ac2e6b0491e      5       1  00:00:00.371
# 1    cc3a9362-5f27-4b31-a11f-f776a3f12858      8       1  00:00:03.866
# 2    916f2f17-c7ba-44b0-bce6-711b100f6d29      9       1  00:00:06.609
# 3    544d2090-8f94-48d1-b78b-f3ffa62ba544     11       1  00:00:21.025
# 4    88a6c333-6ec0-4019-98c7-d1109c3c14ef     14       1  00:00:25.598
# ..                                    ...    ...     ...           ...
# 976  ea1a4c69-03b0-4587-9d2b-0da7cf9e5c5a   3288       2  00:48:19.809
# 977  7e61deaa-1696-4b9d-82a7-f42879067605   3298       2  00:48:24.541
# 978  259a1b8b-3ed8-4ed9-ba17-dd4baec49796   3305       2  00:48:27.239
# ...

# %%
passes.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'type',
#        'possession', 'possession_team', 'play_pattern', 'team', 'player',
#        'position', 'location', 'duration', 'related_events', 'pass',
#        'match_id', 'possession_team_id', 'team_id', 'player_id',
#        'under_pressure', 'off_camera', 'counterpress'],
#       dtype='object')

# %%
passes.location
# Out:
# 0       [60.0, 40.0]
# 1       [41.8, 26.0]
# 2       [29.9, 62.2]
# 3        [63.9, 0.1]
# 4       [20.4, 74.7]
#            ...
# 976    [107.2, 50.4]
# 977    [111.7, 47.7]
# 978      [3.2, 33.6]
# 979    [113.5, 80.0]
# 980    [107.8, 66.6]
# Name: location, Length: 981, dtype: object

# %%
passes['pass'][1]
# Out:
# {'length': 49.07311,
#  'angle': -0.16581869,
#  'height': {'id': 3, 'name': 'High Pass'},
#  'end_location': [90.2, 17.9],
#  'body_part': {'id': 38, 'name': 'Left Foot'},
#  'outcome': {'id': 9, 'name': 'Incomplete'}}

# %%
events = sb.competition_events(
    country="International",
    division= "FIFA World Cup",
    season="2022",
    gender="male")

grouped_events = sb.competition_events(
    country="International",
    division= "FIFA World Cup",
    season="2022",
    split=True
)
# Out:
# C:\Users\DavidB\PycharmProjects\My_Football_Analytics\Football_Analytics_venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\DavidB\PycharmProjects\My_Football_Analytics\Football_Analytics_venv\lib\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events
# Out:
#        50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0        NaN                NaN                  NaN                     NaN
# 1        NaN                NaN                  NaN                     NaN
# 2        NaN                NaN                  NaN                     NaN
# 3        NaN                NaN                  NaN                     NaN
# 4        NaN                NaN                  NaN                     NaN
# ...      ...                ...                  ...                     ...
# 234647   NaN                NaN                  NaN                     NaN
# 234648   NaN                NaN                  NaN                     NaN
# 234649   NaN                NaN                  NaN                     NaN
# 234650   NaN                NaN                  NaN                     NaN
# 234651   NaN                NaN                  NaN                     NaN
#
# ...

# %%
grouped_events['shots']
# Out:
#                                         id  index  period     timestamp  \
# 0     61d52e72-a8ff-49c4-be02-057b1ea0fb15     20       1  00:00:18.696
# 1     aa77495b-0e7b-44f0-a2eb-11605085943a     25       1  00:00:22.129
# 2     51026369-a4ad-4a71-b14a-6e7f8b764772     28       1  00:00:23.845
# 3     6ac240f5-8b84-4c06-8153-b56109c8c5e6    196       1  00:04:35.297
# 4     00e599c0-5234-4b6a-9b91-d6f789a311b0    356       1  00:10:05.636
# ...                                    ...    ...     ...           ...
# 1489  f49396ca-5d50-4662-9f55-6d2a87bfacfd   2846       2  00:24:16.276
# 1490  a0ccad21-8e44-4a4f-ad5e-0eae6a6fcbc2   3077       2  00:30:27.456
# 1491  54778e9f-91a2-49da-912b-d6a68d9d8185   3570       2  00:46:09.522
# 1492  0cb9d4b2-e1ec-403f-99bf-ba2411c0e7e6   3601       2  00:46:41.468
# 1493  0d90f23c-4ee0-49bb-80e3-4be47400729c   3667       2  00:51:18.428
#
#       minute  second  type  possession possession_team   play_pattern  ...  \
# ...
