# %%
import sys
sys.path.append('C:\\Users\\DavidB\\PycharmProjects\\My_Football_Analytics')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mplsoccer import Pitch
from Basics.Pitch.My_Pitch import myPitch 
import matplotlib.image as mpimg
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import plotly.express as px
import plotly.graph_objects as go
from PIL import Image
import numpy as np
from Basics.Data.Statsbomb_Data import match_events
# Out:
# None

# %%
df, teams = match_events(match_id=3857261, event_filter='passes')

# %%
df
# Out:
#                                        id  index  period     timestamp  \
# 0    285b3d0e-ed65-4f11-84ee-1ac2e6b0491e      5       1  00:00:00.371
# 1    cc3a9362-5f27-4b31-a11f-f776a3f12858      8       1  00:00:03.866
# 2    916f2f17-c7ba-44b0-bce6-711b100f6d29      9       1  00:00:06.609
# 3    544d2090-8f94-48d1-b78b-f3ffa62ba544     11       1  00:00:21.025
# 4    88a6c333-6ec0-4019-98c7-d1109c3c14ef     14       1  00:00:25.598
# ..                                    ...    ...     ...           ...
# 976  ea1a4c69-03b0-4587-9d2b-0da7cf9e5c5a   3288       2  00:48:19.809
# 977  7e61deaa-1696-4b9d-82a7-f42879067605   3298       2  00:48:24.541
# 978  259a1b8b-3ed8-4ed9-ba17-dd4baec49796   3305       2  00:48:27.239
# 979  be72239d-9012-4b3d-9049-d7fae8227736   3306       2  00:48:55.723
# 980  359aa65d-c58b-4caf-abca-8609d499ed0e   3313       2  00:48:59.551
#
#      minute  second  type  possession possession_team    play_pattern  ...  \
# 0         0       0  Pass           2           Wales   From Kick Off  ...
# 1         0       3  Pass           2           Wales   From Kick Off  ...
# 2         0       6  Pass           2           Wales   From Kick Off  ...
# 3         0      21  Pass           3           Wales   From Throw In  ...
# 4         0      25  Pass           3           Wales   From Throw In  ...
# ..      ...     ...   ...         ...             ...             ...  ...
# 976      93      19  Pass         156         England  From Free Kick  ...
# 977      93      24  Pass         156         England  From Free Kick  ...
# 978      93      27  Pass         156         England  From Free Kick  ...
# 979      93      55  Pass         157         England   From Throw In  ...
# 980      93      59  Pass         157         England   From Throw In  ...
#
#      duration                                     related_events  \
# 0    1.615000             [b7e37843-7498-42db-b117-ad4d40e0ed8c]
# 1    2.742332             [916f2f17-c7ba-44b0-bce6-711b100f6d29]
# 2    2.893471  [cc3a9362-5f27-4b31-a11f-f776a3f12858, dd4b8fa...
# 3    4.573407  [88a6c333-6ec0-4019-98c7-d1109c3c14ef, 9c31f4d...
# 4    4.625382  [544d2090-8f94-48d1-b78b-f3ffa62ba544, b4c9473...
# ..        ...                                                ...
# 976  0.416533             [c5919be5-1b37-438f-a378-eb91a0f42d6f]
# 977  0.796615             [9e0c67f4-ef33-4a0f-ad8b-b7df08b6dd66]
# 978  2.855230                                                NaN
# 979  1.672468             [069ae913-ee12-4380-88d9-e7ccdc0f62ac]
# 980  1.175440             [c31aab2d-a019-45fd-8578-50ad9b897442]
#
#                                                   pass match_id  \
# 0    {'recipient': {'id': 3086, 'name': 'Ben Davies...  3857261
# 1    {'length': 49.07311, 'angle': -0.16581869, 'he...  3857261
# 2    {'recipient': {'id': 4354, 'name': 'Philip Fod...  3857261
# 3    {'recipient': {'id': 3853, 'name': 'Kieffer Ro...  3857261
# 4    {'recipient': {'id': 10955, 'name': 'Harry Kan...  3857261
# ..                                                 ...      ...
# 976  {'recipient': {'id': 3616, 'name': 'Callum Wil...  3857261
# 977  {'recipient': {'id': 4354, 'name': 'Philip Fod...  3857261
# 978  {'length': 33.672096, 'angle': -1.4696501, 'he...  3857261
# 979  {'recipient': {'id': 9638, 'name': 'Jack Greal...  3857261
# 980  {'recipient': {'id': 3532, 'name': 'Jordan Bri...  3857261
#
#      possession_team_id team_id player_id  under_pressure  off_camera  \
# 0                   907     907      3517             NaN         NaN
# 1                   907     907      3086             NaN         NaN
# 2                   907     768      3943             NaN         NaN
# 3                   907     907      3086             NaN         NaN
# 4                   907     768      3244             NaN         NaN
# ..                  ...     ...       ...             ...         ...
# 976                 768     768      9638             NaN         NaN
# 977                 768     768      9638             NaN         NaN
# 978                 768     907      4774             NaN         NaN
# 979                 768     768      3664             NaN         NaN
# 980                 768     768      9638             NaN         NaN
#
#      counterpress
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 976           NaN
# 977           NaN
# 978           NaN
# 979           NaN
# 980           NaN
#
# [981 rows x 24 columns]

# %%
from Pass_Data import pass_data
passdata = pass_data(df, data_source='Statsbomb', mirror_away=[''])
print(passdata)
# Out:
# pass_data object of Statsbomb of shape (981, 19). Coordinate ranges are (0, 105) for x and (0, 65) for y

# %%
passdata.data
# Out:
#                      player  period  minute  second     team     outcome  \
# 0              Aaron Ramsey       1       0       0    Wales    Complete
# 1                Ben Davies       1       0       3    Wales  Incomplete
# 2               Declan Rice       1       0       6  England         Out
# 3                Ben Davies       1       0      21    Wales  Incomplete
# 4               John Stones       1       0      25  England         Out
# ..                      ...     ...     ...     ...      ...         ...
# 976           Jack Grealish       2      93      19  England    Complete
# 977           Jack Grealish       2      93      24  England    Complete
# 978          Connor Roberts       2      93      27    Wales         Out
# 979  Trent Alexander-Arnold       2      93      55  England    Complete
# 980           Jack Grealish       2      93      59  England    Complete
#
#          type  x_initial  y_initial  x_received  y_received  cross  cut-back  \
# 0    Kick Off    52.5000   32.50000     31.9375    41.68125  False     False
# 1     Regular    36.5750   43.87500     78.9250    50.45625  False     False
# 2    Recovery    26.1625   14.46250     49.7000     0.00000  False     False
# 3    Throw-in    55.9125   64.91875     87.2375    60.61250  False     False
# 4    Recovery    17.8500    4.30625     65.1875     0.00000  False     False
# ..        ...        ...        ...         ...         ...    ...       ...
# 976   Regular    93.8000   24.05000     94.8500    28.19375  False     False
# 977   Regular    97.7375   26.24375     97.1250    25.59375  False     False
# 978   Regular     2.8000   37.70000      5.7750    64.91875  False     False
# 979  Throw-in    99.3125    0.00000     90.9125    18.52500  False     False
# 980   Regular    94.3250   10.88750     85.6625     4.79375  False     False
#
#      switch  shot_assist  goal_assist    play_pattern  \
# 0     False        False        False   From Kick Off
# 1     False        False        False   From Kick Off
# 2     False        False        False   From Kick Off
# 3     False        False        False   From Throw In
# 4     False        False        False   From Throw In
# ..      ...          ...          ...             ...
# 976   False        False        False  From Free Kick
# 977   False         True        False  From Free Kick
# 978   False        False        False  From Free Kick
# 979   False        False        False   From Throw In
# 980   False        False        False   From Throw In
#
#                                         related_events  \
# 0               [b7e37843-7498-42db-b117-ad4d40e0ed8c]
# 1               [916f2f17-c7ba-44b0-bce6-711b100f6d29]
# 2    [cc3a9362-5f27-4b31-a11f-f776a3f12858, dd4b8fa...
# 3    [88a6c333-6ec0-4019-98c7-d1109c3c14ef, 9c31f4d...
# 4    [544d2090-8f94-48d1-b78b-f3ffa62ba544, b4c9473...
# ..                                                 ...
# 976             [c5919be5-1b37-438f-a378-eb91a0f42d6f]
# 977             [9e0c67f4-ef33-4a0f-ad8b-b7df08b6dd66]
# 978                                                NaN
# 979             [069ae913-ee12-4380-88d9-e7ccdc0f62ac]
# 980             [c31aab2d-a019-45fd-8578-50ad9b897442]
#
#                            recipient
# 0                         Ben Davies
# 1                              False
# 2                       Philip Foden
# 3    Kieffer Roberto Francisco Moore
# 4                         Harry Kane
# ..                               ...
# 976                    Callum Wilson
# 977                     Philip Foden
# 978                            False
# 979                    Jack Grealish
# 980           Jordan Brian Henderson
#
# [981 rows x 19 columns]

# %%
pE, pC = passdata.get_passes(get='England')

pBellingham, n = passdata.get_passes(get='Jude Bellingham', data=pE)
pBellingham
# Out:
#               player  period  minute  second     team     outcome      type  \
# 12   Jude Bellingham       1       0      50  England    Complete   Regular
# 17   Jude Bellingham       1       1       8  England    Complete   Regular
# 27   Jude Bellingham       1       1      45  England    Complete   Regular
# 30   Jude Bellingham       1       1      50  England    Complete   Regular
# 43   Jude Bellingham       1       2      32  England    Complete   Regular
# 54   Jude Bellingham       1       3       5  England    Complete   Regular
# 89   Jude Bellingham       1       5      51  England    Complete   Regular
# 124  Jude Bellingham       1       8      37  England    Complete   Regular
# 139  Jude Bellingham       1       9      19  England    Complete   Regular
# 147  Jude Bellingham       1       9      40  England    Complete   Regular
# 205  Jude Bellingham       1      14      56  England    Complete   Regular
# 209  Jude Bellingham       1      15       9  England    Complete   Regular
# 304  Jude Bellingham       1      26      18  England    Complete   Regular
# 336  Jude Bellingham       1      29      58  England    Complete   Regular
# 377  Jude Bellingham       1      32      33  England    Complete   Regular
# 399  Jude Bellingham       1      37       0  England    Complete   Regular
# 402  Jude Bellingham       1      37       7  England    Complete   Regular
# 404  Jude Bellingham       1      37      11  England    Complete   Regular
# 428  Jude Bellingham       1      39      32  England    Complete   Regular
# 438  Jude Bellingham       1      41      24  England    Complete   Regular
# 458  Jude Bellingham       1      43       6  England  Incomplete   Regular
# 461  Jude Bellingham       1      43      28  England    Complete   Regular
# 471  Jude Bellingham       1      43      49  England    Complete   Regular
# 480  Jude Bellingham       1      44      35  England    Complete  Recovery
# 484  Jude Bellingham       1      44      48  England    Complete   Regular
# 516  Jude Bellingham       1      47       4  England    Complete   Regular
# 529  Jude Bellingham       2      45       0  England    Complete  Kick Off
# 546  Jude Bellingham       2      45      56  England    Complete   Regular
# 549  Jude Bellingham       2      46       6  England    Complete   Regular
# 562  Jude Bellingham       2      47      20  England    Complete   Regular
# 564  Jude Bellingham       2      47      23  England    Complete   Regular
# 586  Jude Bellingham       2      52      29  England    Complete   Regular
# 626  Jude Bellingham       2      56      22  England    Complete   Regular
# 633  Jude Bellingham       2      59      24  England    Complete   Regular
# 633    64.6625   62.80625     64.6625    47.61250  False     False   False
# 670    56.2625   23.56250     71.4000    15.11250  False     False   False
# 754    34.9125   32.25625     45.4125    19.01250  False     False   False
# 789     9.0125   61.10000     13.3875    63.05000  False     False   False
# 791    24.2375   56.71250     23.2750    24.05000  False     False    True
# 826    60.2875   50.86250     49.3500    50.70000  False     False   False
# 840    56.3500   38.59375     64.8375    61.83125  False     False   False
# 847    93.9750   42.65625     95.2875    41.03125  False     False   False
# 874    48.5625   50.21250     45.4125    56.71250  False     False   False
# 899    65.1000   64.91875     63.0875    57.20000  False     False   False
# 901    63.3500   62.96875     54.5125    63.05000  False     False   False
# 929    38.5875   51.91875     28.7875    53.78750  False     False   False
# 931    37.1000   55.33125     29.8375    55.33125  False     False   False
# 944    87.0625   25.83750     86.5375    22.91250  False     False   False
# 952    48.7375   24.61875     48.7375    14.38125  False     False   False
# 968    56.5250   52.65000     65.3625    62.80625  False     False   False
# 970    70.8750   59.31250     73.9375    58.01250  False     False   False
# 971    64.5750   61.34375     63.5250    53.13750  False     False   False
# 973    49.0000   38.10625     65.1000    39.81250  False     False   False
#
#      shot_assist  goal_assist    play_pattern  \
# 12         False        False    Regular Play
# 17         False        False    Regular Play
# 27         False        False    Regular Play
# 30         False        False    Regular Play
# 43         False        False    Regular Play
# 54         False        False    Regular Play
# 89         False        False    Regular Play
# 124        False        False   From Throw In
# 139        False        False    Regular Play
# 147        False        False    Regular Play
# 205        False        False   From Throw In
# 209        False        False   From Throw In
# 304        False        False   From Throw In
# 336        False        False    Regular Play
# 377        False        False   From Throw In
# 399        False        False    Regular Play
# 402        False        False    Regular Play
# 404         True        False    Regular Play
# 428        False        False    Regular Play
# 438        False        False   From Throw In
# 458        False        False    Regular Play
# 461        False        False  From Free Kick
# 471         True        False  From Free Kick
# 480        False        False    Regular Play
# 484        False        False    Regular Play
# 516        False        False    Regular Play
# 529        False        False   From Kick Off
# 546        False        False    Regular Play
# 549        False        False    Regular Play
# 562        False        False  From Free Kick
# 564        False        False  From Free Kick
# 586        False        False    Regular Play
# 626        False        False  From Free Kick
# 633        False        False  From Free Kick
# 670        False        False    Regular Play
# 754        False        False    Regular Play
# 789        False        False    Regular Play
# 791        False        False    Regular Play
# 826        False        False    Regular Play
# 840        False        False    Regular Play
# 847        False        False    Regular Play
# 874        False        False  From Goal Kick
# 899        False        False   From Throw In
# 901        False        False   From Throw In
# 929        False        False  From Free Kick
# 931        False        False  From Free Kick
# 944        False        False  From Free Kick
# 952        False        False    Regular Play
# 968        False        False  From Free Kick
# 970        False        False  From Free Kick
# 971        False        False  From Free Kick
# 973        False        False  From Free Kick
#
#                                         related_events               recipient
# 12              [e6b312b3-f913-4835-8a4a-b6b3722ca506]              Harry Kane
# 17   [51abba94-63a1-4c94-9a8b-e3cfd180648b, 8345ef2...            Philip Foden
# 27              [57dbf37b-bd79-4643-9d0c-e4b70c408821]         Marcus Rashford
# 30              [6b7f3ad1-dfab-4b2f-a5e0-987eb6598b5c]             John Stones
# 43              [88bc24ed-c483-459c-a421-fac102671516]             John Stones
# 901             [7660636a-120b-4c6e-86f3-48cdc7f2491a]         Kieran Trippier
# 929             [91869a98-1183-4d29-956a-da753d2f8aa7]           Harry Maguire
# 931             [265e158b-ae90-4232-9956-4c730dfbe65c]           Harry Maguire
# 944  [12ae5b26-1943-4803-bbdb-90b7c690ff14, 8b08cc6...           Callum Wilson
# 952             [6689ea6c-2a5b-4e80-9642-4b8fff78cfe3]  Jordan Brian Henderson
# 968             [77892e6e-fa40-417c-ae5d-b630147d8033]           Jack Grealish
# 970  [40a32503-3c73-4293-ba85-c55f889a3b16, 7528eeb...           Jack Grealish
# 971  [3b99ad06-177b-495f-b582-59f1350af73a, c480140...         Kalvin Phillips
# 973             [841f8acf-0451-4bfb-8916-6f844d59d3e3]           Jack Grealish

# %%
pm = passdata.pass_map(pdop_y=-0.025, pdop_o=1,data=pBellingham)

# %%
passdata2 = pass_data(df, data_source='Statsbomb', mirror_away=[''], scale_to_pitch='myPitch')
print(passdata2)
# Out:
# pass_data object of Statsbomb of shape (981, 19). Coordinate ranges are (0, 105) for x and (0, 65) for y

# %%
pBellingham, n = passdata2.get_passes(get='Jude Bellingham')
pBellingham
# Out:
#               player  period  minute  second     team     outcome      type  \
# 12   Jude Bellingham       1       0      50  England    Complete   Regular
# 17   Jude Bellingham       1       1       8  England    Complete   Regular
# 27   Jude Bellingham       1       1      45  England    Complete   Regular
# 30   Jude Bellingham       1       1      50  England    Complete   Regular
# 43   Jude Bellingham       1       2      32  England    Complete   Regular
# 54   Jude Bellingham       1       3       5  England    Complete   Regular
# 89   Jude Bellingham       1       5      51  England    Complete   Regular
# 124  Jude Bellingham       1       8      37  England    Complete   Regular
# 139  Jude Bellingham       1       9      19  England    Complete   Regular
# 147  Jude Bellingham       1       9      40  England    Complete   Regular
# 205  Jude Bellingham       1      14      56  England    Complete   Regular
# 209  Jude Bellingham       1      15       9  England    Complete   Regular
# 304  Jude Bellingham       1      26      18  England    Complete   Regular
# 336  Jude Bellingham       1      29      58  England    Complete   Regular
# 377  Jude Bellingham       1      32      33  England    Complete   Regular
# 399  Jude Bellingham       1      37       0  England    Complete   Regular
# 402  Jude Bellingham       1      37       7  England    Complete   Regular
# 404  Jude Bellingham       1      37      11  England    Complete   Regular
# 428  Jude Bellingham       1      39      32  England    Complete   Regular
# 438  Jude Bellingham       1      41      24  England    Complete   Regular
# 458  Jude Bellingham       1      43       6  England  Incomplete   Regular
# 461  Jude Bellingham       1      43      28  England    Complete   Regular
# 471  Jude Bellingham       1      43      49  England    Complete   Regular
# 480  Jude Bellingham       1      44      35  England    Complete  Recovery
# 484  Jude Bellingham       1      44      48  England    Complete   Regular
# 516  Jude Bellingham       1      47       4  England    Complete   Regular
# 529  Jude Bellingham       2      45       0  England    Complete  Kick Off
# 546  Jude Bellingham       2      45      56  England    Complete   Regular
# 549  Jude Bellingham       2      46       6  England    Complete   Regular
# 562  Jude Bellingham       2      47      20  England    Complete   Regular
# 564  Jude Bellingham       2      47      23  England    Complete   Regular
# 586  Jude Bellingham       2      52      29  England    Complete   Regular
# 626  Jude Bellingham       2      56      22  England    Complete   Regular
# 633    64.6625   62.80625     64.6625    47.61250  False     False   False
# 670    56.2625   23.56250     71.4000    15.11250  False     False   False
# 754    34.9125   32.25625     45.4125    19.01250  False     False   False
# 789     9.0125   61.10000     13.3875    63.05000  False     False   False
# 791    24.2375   56.71250     23.2750    24.05000  False     False    True
# 826    60.2875   50.86250     49.3500    50.70000  False     False   False
# 840    56.3500   38.59375     64.8375    61.83125  False     False   False
# 847    93.9750   42.65625     95.2875    41.03125  False     False   False
# 874    48.5625   50.21250     45.4125    56.71250  False     False   False
# 899    65.1000   64.91875     63.0875    57.20000  False     False   False
# 901    63.3500   62.96875     54.5125    63.05000  False     False   False
# 929    38.5875   51.91875     28.7875    53.78750  False     False   False
# 931    37.1000   55.33125     29.8375    55.33125  False     False   False
# 944    87.0625   25.83750     86.5375    22.91250  False     False   False
# 952    48.7375   24.61875     48.7375    14.38125  False     False   False
# 968    56.5250   52.65000     65.3625    62.80625  False     False   False
# 970    70.8750   59.31250     73.9375    58.01250  False     False   False
# 971    64.5750   61.34375     63.5250    53.13750  False     False   False
# 973    49.0000   38.10625     65.1000    39.81250  False     False   False
#
#      shot_assist  goal_assist    play_pattern  \
# 12         False        False    Regular Play
# 17         False        False    Regular Play
# 27         False        False    Regular Play
# 30         False        False    Regular Play
# 43         False        False    Regular Play
# 54         False        False    Regular Play
# 89         False        False    Regular Play
# 124        False        False   From Throw In
# 139        False        False    Regular Play
# 147        False        False    Regular Play
# 205        False        False   From Throw In
# 209        False        False   From Throw In
# 304        False        False   From Throw In
# 336        False        False    Regular Play
# 377        False        False   From Throw In
# 399        False        False    Regular Play
# 402        False        False    Regular Play
# 404         True        False    Regular Play
# 428        False        False    Regular Play
# 438        False        False   From Throw In
# 458        False        False    Regular Play
# 461        False        False  From Free Kick
# 471         True        False  From Free Kick
# 480        False        False    Regular Play
# 484        False        False    Regular Play
# 516        False        False    Regular Play
# 529        False        False   From Kick Off
# 546        False        False    Regular Play
# 549        False        False    Regular Play
# 562        False        False  From Free Kick
# 564        False        False  From Free Kick
# 586        False        False    Regular Play
# 626        False        False  From Free Kick
# 633        False        False  From Free Kick
# 670        False        False    Regular Play
# 754        False        False    Regular Play
# 789        False        False    Regular Play
# 791        False        False    Regular Play
# 826        False        False    Regular Play
# 840        False        False    Regular Play
# 847        False        False    Regular Play
# 874        False        False  From Goal Kick
# 899        False        False   From Throw In
# 901        False        False   From Throw In
# 929        False        False  From Free Kick
# 931        False        False  From Free Kick
# 944        False        False  From Free Kick
# 952        False        False    Regular Play
# 968        False        False  From Free Kick
# 970        False        False  From Free Kick
# 971        False        False  From Free Kick
# 973        False        False  From Free Kick
#
#                                         related_events               recipient
# 12              [e6b312b3-f913-4835-8a4a-b6b3722ca506]              Harry Kane
# 17   [51abba94-63a1-4c94-9a8b-e3cfd180648b, 8345ef2...            Philip Foden
# 27              [57dbf37b-bd79-4643-9d0c-e4b70c408821]         Marcus Rashford
# 30              [6b7f3ad1-dfab-4b2f-a5e0-987eb6598b5c]             John Stones
# 43              [88bc24ed-c483-459c-a421-fac102671516]             John Stones
# 901             [7660636a-120b-4c6e-86f3-48cdc7f2491a]         Kieran Trippier
# 929             [91869a98-1183-4d29-956a-da753d2f8aa7]           Harry Maguire
# 931             [265e158b-ae90-4232-9956-4c730dfbe65c]           Harry Maguire
# 944  [12ae5b26-1943-4803-bbdb-90b7c690ff14, 8b08cc6...           Callum Wilson
# 952             [6689ea6c-2a5b-4e80-9642-4b8fff78cfe3]  Jordan Brian Henderson
# 968             [77892e6e-fa40-417c-ae5d-b630147d8033]           Jack Grealish
# 970  [40a32503-3c73-4293-ba85-c55f889a3b16, 7528eeb...           Jack Grealish
# 971  [3b99ad06-177b-495f-b582-59f1350af73a, c480140...         Kalvin Phillips
# 973             [841f8acf-0451-4bfb-8916-6f844d59d3e3]           Jack Grealish

# %%
pm = passdata2.pass_map(pdop_y=1.05, pdop_o=1,data=pBellingham, pitch_col='#96b279')

# %% [markdown]
# # Pass network

# %%
import sys
sys.path.append('C:\\Users\\DavidB\\PycharmProjects\\My_Football_Analytics\\Basics')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mplsoccer import Pitch
from Pitch.My_Pitch import \
    myPitch  # might need adaptation of path depending on whether it is used in pycharm or jupyter notebook
import matplotlib.image as mpimg
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import plotly.express as px
import plotly.graph_objects as go
from PIL import Image
import numpy as np
from Data.Statsbomb_Data import match_events
# Out:
# None

# %%
df, teams = match_events(match_id=3857261, event_filter='passes')
from Pass_Data import pass_data
passdata = pass_data(df, data_source='Statsbomb', mirror_away=[''])
print(passdata)
pE, pC = passdata.get_passes(get='England')
pE
# Out:
# pass_data object of Statsbomb of shape (981, 19). Coordinate ranges are (0, 105) for x and (0, 65) for y
#                      player  period  minute  second     team   outcome  \
# 2               Declan Rice       1       0       6  England       Out
# 4               John Stones       1       0      25  England       Out
# 11   Jordan Brian Henderson       1       0      46  England  Complete
# 12          Jude Bellingham       1       0      50  England  Complete
# 13               Harry Kane       1       0      50  England       Out
# ..                      ...     ...     ...     ...      ...       ...
# 975  Jordan Brian Henderson       2      93      15  England  Complete
# 976           Jack Grealish       2      93      19  England  Complete
# 977           Jack Grealish       2      93      24  England  Complete
# 979  Trent Alexander-Arnold       2      93      55  England  Complete
# 980           Jack Grealish       2      93      59  England  Complete
#
#          type  x_initial  y_initial  x_received  y_received  cross  cut-back  \
# 2    Recovery    26.1625   14.46250     49.7000     0.00000  False     False
# 4    Recovery    17.8500    4.30625     65.1875     0.00000  False     False
# 11   Recovery    70.0000    5.28125     70.1750     1.05625  False     False
# 12    Regular    70.3500    2.51875     74.1125     8.04375  False     False
# 13    Regular    73.9375    8.04375     59.6750     0.00000  False     False
# ..        ...        ...        ...         ...         ...    ...       ...
# 975   Regular    71.9250   34.93750     71.1375    30.79375  False     False
# 976   Regular    93.8000   24.05000     94.8500    28.19375  False     False
# 977   Regular    97.7375   26.24375     97.1250    25.59375  False     False
# 979  Throw-in    99.3125    0.00000     90.9125    18.52500  False     False
# 980   Regular    94.3250   10.88750     85.6625     4.79375  False     False
#
#      switch  shot_assist  goal_assist    play_pattern  \
# 2     False        False        False   From Kick Off
# 4     False        False        False   From Throw In
# 11    False        False        False    Regular Play
# 12    False        False        False    Regular Play
# 13    False        False        False    Regular Play
# ..      ...          ...          ...             ...
# 975   False        False        False  From Free Kick
# 976   False        False        False  From Free Kick
# 977   False         True        False  From Free Kick
# 979   False        False        False   From Throw In
# 980   False        False        False   From Throw In
#
#                                         related_events               recipient
# 2    [cc3a9362-5f27-4b31-a11f-f776a3f12858, dd4b8fa...            Philip Foden
# 4    [544d2090-8f94-48d1-b78b-f3ffa62ba544, b4c9473...              Harry Kane
# 11   [4f00b46f-ee51-4377-8a43-4b4054cc0364, b0fff6e...         Jude Bellingham
# 12              [e6b312b3-f913-4835-8a4a-b6b3722ca506]              Harry Kane
# 13              [4a8cdb84-358c-4820-9c83-aff4ffb1f8bb]             Kyle Walker
# ..                                                 ...                     ...
# 975             [a51c9035-edee-4e2f-9972-5d6893455952]           Jack Grealish
# 976             [c5919be5-1b37-438f-a378-eb91a0f42d6f]           Callum Wilson
# 977             [9e0c67f4-ef33-4a0f-ad8b-b7df08b6dd66]            Philip Foden
# 979             [069ae913-ee12-4380-88d9-e7ccdc0f62ac]           Jack Grealish
# 980             [c31aab2d-a019-45fd-8578-50ad9b897442]  Jordan Brian Henderson
#
# [630 rows x 19 columns]

# %%
net_fig, net_dict = passdata.pass_network(data=pE)

# %%
net_dict
# Out:
# {'Declan Rice': {'x_avg': 56.43020833333333,
#   'y_avg': 36.40677083333333,
#   'n': 48,
#   'n_complete': 45,
#   'receivers': {'Philip Foden': 5,
#    'Jude Bellingham': 2,
#    'Luke Shaw': 12,
#    'Harry Maguire': 8,
#    'John Stones': 5,
#    'Jordan Brian Henderson': 6,
#    'Harry Kane': 1,
#    'Marcus Rashford': 6,
#    'Kyle Walker': 3}},
#  'John Stones': {'x_avg': 39.42301829268292,
#   'y_avg': 22.009832317073172,
#   'n': 82,
#   'n_complete': 75,
#   'receivers': {'Harry Kane': 2,
#    'Jordan Brian Henderson': 16,
#    'Kyle Walker': 14,
#    'Jordan Pickford': 5,
#    'Harry Maguire': 19,
#    'Declan Rice': 4,
#    'Luke Shaw': 2,
#    'Philip Foden': 2,
#    'Marcus Rashford': 2,
#    'Jude Bellingham': 2}},
#  'Jordan Brian Henderson': {'x_avg': 61.714754098360665,
#   'y_avg': 18.896618852459014,
#   'n': 61,
#   'n_complete': 50,
#   'receivers': {'Jude Bellingham': 5,
#    'John Stones': 5,
#    'Philip Foden': 10,
#    'Kyle Walker': 9,
#    'Harry Maguire': 5,
#    'Harry Kane': 3,
#    'Jordan Pickford': 4,
#    'Declan Rice': 3,
#    'Marcus Rashford': 7}},
#  'Jude Bellingham': {'x_avg': 56.232211538461534,
#   'y_avg': 40.129687499999996,
#   'n': 52,
#   'n_complete': 47,
#   'receivers': {'Harry Kane': 3,
#    'Philip Foden': 6,
#    'Marcus Rashford': 4,
#    'John Stones': 5,
#    'Luke Shaw': 9,
#    'Kyle Walker': 3,
#    'Harry Maguire': 3,
#    'Declan Rice': 2,
#    'Jordan Brian Henderson': 3}},
#  'Harry Kane': {'x_avg': 76.07638888888889,
#   'y_avg': 32.68055555555556,
#   'n': 9,
#   'n_complete': 7,
#   'receivers': {'Kyle Walker': 1,
#    'Marcus Rashford': 4,
#    'Jude Bellingham': 2,
#    'Declan Rice': 1,
#    'Philip Foden': 1}},
#  'Philip Foden': {'x_avg': 75.02395833333334,
#   'y_avg': 17.972048611111106,
#   'n': 36,
#   'n_complete': 27,
#   'receivers': {'John Stones': 4,
#    'Kyle Walker': 7,
#    'Jordan Brian Henderson': 10,
#    'Marcus Rashford': 1,
#    'Declan Rice': 2,
#    'Harry Kane': 1,
#    'Jude Bellingham': 1,
#    'Luke Shaw': 1,
#    'Harry Maguire': 1}},
#  'Kyle Walker': {'x_avg': 58.45318181818182,
#   'y_avg': 10.589090909090908,
#   'n': 55,
#   'n_complete': 50,
#   'receivers': {'Harry Maguire': 4,
#    'Jude Bellingham': 8,
#    'Harry Kane': 2,
#    'Jordan Pickford': 3,
#    'John Stones': 13,
#    'Philip Foden': 8,
#    'Jordan Brian Henderson': 6,
#    'Luke Shaw': 1,
#    'Declan Rice': 6,
#    'Marcus Rashford': 1}},
#  'Harry Maguire': {'x_avg': 36.894827586206894,
#   'y_avg': 45.54576149425288,
#   'n': 87,
#   'n_complete': 77,
#   'receivers': {'Marcus Rashford': 5,
#    'Luke Shaw': 18,
#    'John Stones': 21,
#    'Jude Bellingham': 6,
#    'Declan Rice': 7,
#    'Jordan Pickford': 8,
#    'Kyle Walker': 3,
#    'Philip Foden': 3,
#    'Jordan Brian Henderson': 2}},
#  'Marcus Rashford': {'x_avg': 65.06895161290322,
#   'y_avg': 42.63266129032258,
#   'n': 31,
#   'n_complete': 23,
#   'receivers': {'Jude Bellingham': 2,
#    'Declan Rice': 4,
#    'Luke Shaw': 10,
#    'Harry Maguire': 4,
#    'Harry Kane': 2,
#    'Jordan Brian Henderson': 5,
#    'Kyle Walker': 2}},
#  'Jordan Pickford': {'x_avg': 13.056640625,
#   'y_avg': 34.66328125,
#   'n': 32,
#   'n_complete': 29,
#   'receivers': {'Harry Maguire': 15,
#    'Kyle Walker': 2,
#    'John Stones': 11,
#    'Harry Kane': 1}},
#  'Luke Shaw': {'x_avg': 60.32833333333333,
#   'y_avg': 57.068645833333335,
#   'n': 60,
#   'n_complete': 51,
#   'receivers': {'Marcus Rashford': 12,
#    'Harry Maguire': 13,
#    'Jude Bellingham': 14,
#    'Declan Rice': 8,
#    'Harry Kane': 6,
#    'Jordan Brian Henderson': 2,
#    'John Stones': 1,
#    'Philip Foden': 3}}}

# %%
# by received position
net_fig, net_dict = passdata.pass_network(data=pE, by_receive=True)

# %%
net_dict
# Out:
# {'Declan Rice': {'x_avg': 57.0570945945946,
#   'y_avg': 37.473817567567565,
#   'n': 37,
#   'n_complete': 36,
#   'passers': {'Marcus Rashford': 4,
#    'John Stones': 4,
#    'Harry Maguire': 7,
#    'Luke Shaw': 8,
#    'Jude Bellingham': 2,
#    'Kyle Walker': 6,
#    'Jordan Brian Henderson': 3,
#    'Philip Foden': 2,
#    'Harry Kane': 1}},
#  'John Stones': {'x_avg': 37.3515625,
#   'y_avg': 23.249913194444446,
#   'n': 72,
#   'n_complete': 72,
#   'passers': {'Jude Bellingham': 5,
#    'Jordan Brian Henderson': 5,
#    'Harry Maguire': 21,
#    'Philip Foden': 4,
#    'Declan Rice': 5,
#    'Jordan Pickford': 11,
#    'Kyle Walker': 13,
#    'Luke Shaw': 1}},
#  'Jordan Brian Henderson': {'x_avg': 62.2125,
#   'y_avg': 18.244188596491227,
#   'n': 57,
#   'n_complete': 52,
#   'passers': {'John Stones': 16,
#    'Declan Rice': 6,
#    'Kyle Walker': 6,
#    'Philip Foden': 10,
#    'Luke Shaw': 2,
#    'Jude Bellingham': 3,
#    'Marcus Rashford': 5,
#    'Harry Maguire': 2}},
#  'Jude Bellingham': {'x_avg': 61.18636363636364,
#   'y_avg': 41.14056818181819,
#   'n': 55,
#   'n_complete': 48,
#   'passers': {'Jordan Brian Henderson': 5,
#    'Marcus Rashford': 2,
#    'Declan Rice': 2,
#    'Luke Shaw': 14,
#    'Kyle Walker': 8,
#    'Harry Maguire': 6,
#    'Harry Kane': 2,
#    'John Stones': 2,
#    'Philip Foden': 1}},
#  'Harry Kane': {'x_avg': 74.87083333333332,
#   'y_avg': 31.199999999999996,
#   'n': 21,
#   'n_complete': 13,
#   'passers': {'John Stones': 2,
#    'Jude Bellingham': 3,
#    'Kyle Walker': 2,
#    'Jordan Brian Henderson': 3,
#    'Declan Rice': 1,
#    'Luke Shaw': 6,
#    'Jordan Pickford': 1,
#    'Marcus Rashford': 2,
#    'Philip Foden': 1}},
#  'Philip Foden': {'x_avg': 71.02151162790697,
#   'y_avg': 19.199563953488372,
#   'n': 43,
#   'n_complete': 34,
#   'passers': {'Declan Rice': 5,
#    'Jude Bellingham': 6,
#    'Jordan Brian Henderson': 10,
#    'Kyle Walker': 8,
#    'John Stones': 2,
#    'Harry Maguire': 3,
#    'Luke Shaw': 3,
#    'Harry Kane': 1}},
#  'Kyle Walker': {'x_avg': 55.7096590909091,
#   'y_avg': 11.875426136363638,
#   'n': 44,
#   'n_complete': 40,
#   'passers': {'Harry Kane': 1,
#    'John Stones': 14,
#    'Jordan Brian Henderson': 9,
#    'Jordan Pickford': 2,
#    'Jude Bellingham': 3,
#    'Harry Maguire': 3,
#    'Philip Foden': 7,
#    'Declan Rice': 3,
#    'Marcus Rashford': 2}},
#  'Harry Maguire': {'x_avg': 35.411144578313255,
#   'y_avg': 45.04088855421688,
#   'n': 83,
#   'n_complete': 82,
#   'passers': {'Kyle Walker': 4,
#    'Jordan Pickford': 15,
#    'Luke Shaw': 13,
#    'John Stones': 19,
#    'Marcus Rashford': 4,
#    'Declan Rice': 8,
#    'Jordan Brian Henderson': 5,
#    'Jude Bellingham': 3,
#    'Philip Foden': 1}},
#  'Marcus Rashford': {'x_avg': 69.21436170212766,
#   'y_avg': 36.62127659574468,
#   'n': 47,
#   'n_complete': 34,
#   'passers': {'Harry Maguire': 5,
#    'Jude Bellingham': 4,
#    'Luke Shaw': 12,
#    'Harry Kane': 4,
#    'Declan Rice': 6,
#    'Jordan Brian Henderson': 7,
#    'Philip Foden': 1,
#    'John Stones': 2,
#    'Kyle Walker': 1}},
#  'Jordan Pickford': {'x_avg': 12.771499999999998,
#   'y_avg': 32.721,
#   'n': 25,
#   'n_complete': 25,
#   'passers': {'John Stones': 5,
#    'Harry Maguire': 8,
#    'Kyle Walker': 3,
#    'Jordan Brian Henderson': 4}},
#  'Luke Shaw': {'x_avg': 60.445990566037736,
#   'y_avg': 56.775353773584904,
#   'n': 53,
#   'n_complete': 51,
#   'passers': {'Harry Maguire': 18,
#    'Marcus Rashford': 10,
#    'Declan Rice': 12,
#    'Jude Bellingham': 9,
#    'John Stones': 2,
#    'Kyle Walker': 1,
#    'Philip Foden': 1}}}

# %%
df, teams = match_events(match_id=3857261, event_filter='passes')
from Pass_Data import pass_data
passdata = pass_data(df, data_source='Statsbomb', mirror_away=[''], scale_to_pitch='myPitch')
print(passdata)
pE, pC = passdata.get_passes(get='England')
pE
# Out:
# pass_data object of Statsbomb of shape (981, 19). Coordinate ranges are (0, 105) for x and (0, 65) for y
#                      player  period  minute  second     team   outcome  \
# 2               Declan Rice       1       0       6  England       Out
# 4               John Stones       1       0      25  England       Out
# 11   Jordan Brian Henderson       1       0      46  England  Complete
# 12          Jude Bellingham       1       0      50  England  Complete
# 13               Harry Kane       1       0      50  England       Out
# ..                      ...     ...     ...     ...      ...       ...
# 975  Jordan Brian Henderson       2      93      15  England  Complete
# 976           Jack Grealish       2      93      19  England  Complete
# 977           Jack Grealish       2      93      24  England  Complete
# 979  Trent Alexander-Arnold       2      93      55  England  Complete
# 980           Jack Grealish       2      93      59  England  Complete
#
#          type  x_initial  y_initial  x_received  y_received  cross  cut-back  \
# 2    Recovery    26.1625   14.46250     49.7000     0.00000  False     False
# 4    Recovery    17.8500    4.30625     65.1875     0.00000  False     False
# 11   Recovery    70.0000    5.28125     70.1750     1.05625  False     False
# 12    Regular    70.3500    2.51875     74.1125     8.04375  False     False
# 13    Regular    73.9375    8.04375     59.6750     0.00000  False     False
# ..        ...        ...        ...         ...         ...    ...       ...
# 975   Regular    71.9250   34.93750     71.1375    30.79375  False     False
# 976   Regular    93.8000   24.05000     94.8500    28.19375  False     False
# 977   Regular    97.7375   26.24375     97.1250    25.59375  False     False
# 979  Throw-in    99.3125    0.00000     90.9125    18.52500  False     False
# 980   Regular    94.3250   10.88750     85.6625     4.79375  False     False
#
#      switch  shot_assist  goal_assist    play_pattern  \
# 2     False        False        False   From Kick Off
# 4     False        False        False   From Throw In
# 11    False        False        False    Regular Play
# 12    False        False        False    Regular Play
# 13    False        False        False    Regular Play
# ..      ...          ...          ...             ...
# 975   False        False        False  From Free Kick
# 976   False        False        False  From Free Kick
# 977   False         True        False  From Free Kick
# 979   False        False        False   From Throw In
# 980   False        False        False   From Throw In
#
#                                         related_events               recipient
# 2    [cc3a9362-5f27-4b31-a11f-f776a3f12858, dd4b8fa...            Philip Foden
# 4    [544d2090-8f94-48d1-b78b-f3ffa62ba544, b4c9473...              Harry Kane
# 11   [4f00b46f-ee51-4377-8a43-4b4054cc0364, b0fff6e...         Jude Bellingham
# 12              [e6b312b3-f913-4835-8a4a-b6b3722ca506]              Harry Kane
# 13              [4a8cdb84-358c-4820-9c83-aff4ffb1f8bb]             Kyle Walker
# ..                                                 ...                     ...
# 975             [a51c9035-edee-4e2f-9972-5d6893455952]           Jack Grealish
# 976             [c5919be5-1b37-438f-a378-eb91a0f42d6f]           Callum Wilson
# 977             [9e0c67f4-ef33-4a0f-ad8b-b7df08b6dd66]            Philip Foden
# 979             [069ae913-ee12-4380-88d9-e7ccdc0f62ac]           Jack Grealish
# 980             [c31aab2d-a019-45fd-8578-50ad9b897442]  Jordan Brian Henderson
#
# [630 rows x 19 columns]

# %%
passdata.pass_network(data=pE, pitch_col='#96b279')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  {'Declan Rice': {'x_avg': 56.43020833333333,
#    'y_avg': 36.40677083333333,
#    'n': 48,
#    'n_complete': 45,
#    'receivers': {'Philip Foden': 5,
#     'Jude Bellingham': 2,
#     'Luke Shaw': 12,
#     'Harry Maguire': 8,
#     'John Stones': 5,
#     'Jordan Brian Henderson': 6,
#     'Harry Kane': 1,
#     'Marcus Rashford': 6,
#     'Kyle Walker': 3}},
#   'John Stones': {'x_avg': 39.42301829268292,
#    'y_avg': 22.009832317073172,
#    'n': 82,
#    'n_complete': 75,
#    'receivers': {'Harry Kane': 2,
#     'Jordan Brian Henderson': 16,
#     'Kyle Walker': 14,
#     'Jordan Pickford': 5,
#     'Harry Maguire': 19,
#     'Declan Rice': 4,
#     'Luke Shaw': 2,
#     'Philip Foden': 2,
#     'Marcus Rashford': 2,
#     'Jude Bellingham': 2}},
#   'Jordan Brian Henderson': {'x_avg': 61.714754098360665,
#    'y_avg': 18.896618852459014,
#    'n': 61,
#    'n_complete': 50,
#    'receivers': {'Jude Bellingham': 5,
#     'John Stones': 5,
#     'Philip Foden': 10,
#     'Kyle Walker': 9,
#     'Harry Maguire': 5,
#     'Harry Kane': 3,
#     'Jordan Pickford': 4,
#     'Declan Rice': 3,
#     'Marcus Rashford': 7}},
#   'Jude Bellingham': {'x_avg': 56.232211538461534,
#    'y_avg': 40.129687499999996,
#    'n': 52,
#    'n_complete': 47,
#    'receivers': {'Harry Kane': 3,
#     'Philip Foden': 6,
#     'Marcus Rashford': 4,
#     'John Stones': 5,
#     'Luke Shaw': 9,
#     'Kyle Walker': 3,
#     'Harry Maguire': 3,
#     'Declan Rice': 2,
#     'Jordan Brian Henderson': 3}},
#   'Harry Kane': {'x_avg': 76.07638888888889,
#    'y_avg': 32.68055555555556,
#    'n': 9,
#    'n_complete': 7,
#    'receivers': {'Kyle Walker': 1,
#     'Marcus Rashford': 4,
#     'Jude Bellingham': 2,
#     'Declan Rice': 1,
#     'Philip Foden': 1}},
#   'Philip Foden': {'x_avg': 75.02395833333334,
#    'y_avg': 17.972048611111106,
#    'n': 36,
#    'n_complete': 27,
#    'receivers': {'John Stones': 4,
#     'Kyle Walker': 7,
#     'Jordan Brian Henderson': 10,
#     'Marcus Rashford': 1,
#     'Declan Rice': 2,
#     'Harry Kane': 1,
#     'Jude Bellingham': 1,
#     'Luke Shaw': 1,
#     'Harry Maguire': 1}},
#   'Kyle Walker': {'x_avg': 58.45318181818182,
#    'y_avg': 10.589090909090908,
#    'n': 55,
#    'n_complete': 50,
#    'receivers': {'Harry Maguire': 4,
#     'Jude Bellingham': 8,
#     'Harry Kane': 2,
#     'Jordan Pickford': 3,
#     'John Stones': 13,
#     'Philip Foden': 8,
#     'Jordan Brian Henderson': 6,
#     'Luke Shaw': 1,
#     'Declan Rice': 6,
#     'Marcus Rashford': 1}},
#   'Harry Maguire': {'x_avg': 36.894827586206894,
#    'y_avg': 45.54576149425288,
#    'n': 87,
#    'n_complete': 77,
#    'receivers': {'Marcus Rashford': 5,
#     'Luke Shaw': 18,
#     'John Stones': 21,
#     'Jude Bellingham': 6,
#     'Declan Rice': 7,
#     'Jordan Pickford': 8,
#     'Kyle Walker': 3,
#     'Philip Foden': 3,
#     'Jordan Brian Henderson': 2}},
#   'Marcus Rashford': {'x_avg': 65.06895161290322,
#    'y_avg': 42.63266129032258,
#    'n': 31,
#    'n_complete': 23,
#    'receivers': {'Jude Bellingham': 2,
#     'Declan Rice': 4,
#     'Luke Shaw': 10,
#     'Harry Maguire': 4,
#     'Harry Kane': 2,
#     'Jordan Brian Henderson': 5,
#     'Kyle Walker': 2}},
#   'Jordan Pickford': {'x_avg': 13.056640625,
#    'y_avg': 34.66328125,
#    'n': 32,
#    'n_complete': 29,
#    'receivers': {'Harry Maguire': 15,
#     'Kyle Walker': 2,
#     'John Stones': 11,
#     'Harry Kane': 1}},
#   'Luke Shaw': {'x_avg': 60.32833333333333,
#    'y_avg': 57.068645833333335,
#    'n': 60,
#    'n_complete': 51,
#    'receivers': {'Marcus Rashford': 12,
#     'Harry Maguire': 13,
#     'Jude Bellingham': 14,
#     'Declan Rice': 8,
#     'Harry Kane': 6,
#     'Jordan Brian Henderson': 2,
#     'John Stones': 1,
#     'Philip Foden': 3}}})

# %%
df, teams = match_events(match_id=3857261, event_filter='passes')
from Pass_Data import pass_data
passdata = pass_data(df, data_source='Statsbomb', mirror_away=[''], scale_to_pitch='myPitch')
print(passdata)
pW, pC = passdata.get_passes(get='Wales')
pW
# Out:
# pass_data object of Statsbomb of shape (981, 19). Coordinate ranges are (0, 105) for x and (0, 65) for y
#                               player  period  minute  second   team  \
# 0                       Aaron Ramsey       1       0       0  Wales
# 1                         Ben Davies       1       0       3  Wales
# 3                         Ben Davies       1       0      21  Wales
# 5                         Ben Davies       1       0      39  Wales
# 6                       Aaron Ramsey       1       0      40  Wales
# ..                               ...     ...     ...     ...    ...
# 909                     Ethan Ampadu       2      86       9  Wales
# 918                   Joseff Morrell       2      87      46  Wales
# 949                       Danny Ward       2      91      21  Wales
# 950  Kieffer Roberto Francisco Moore       2      91      25  Wales
# 978                   Connor Roberts       2      93      27  Wales
#
#         outcome       type  x_initial  y_initial  x_received  y_received  \
# 0      Complete   Kick Off    52.5000   32.50000     31.9375    41.68125
# 1    Incomplete    Regular    36.5750   43.87500     78.9250    50.45625
# 3    Incomplete   Throw-in    55.9125   64.91875     87.2375    60.61250
# 5      Complete   Throw-in    38.1500   64.91875     44.6250    61.10000
# 6      Complete    Regular    44.6250   61.10000     37.1000    64.26875
# ..          ...        ...        ...        ...         ...         ...
# 909    Complete    Regular    71.1375    7.63750     86.8000    39.16250
# 918  Incomplete    Regular    45.5875   23.48125     60.7250    13.24375
# 949    Complete  Goal Kick     6.1250   29.16875     65.7125    49.07500
# 950  Incomplete    Regular    65.4500   48.83125     70.6125    30.14375
# 978         Out    Regular     2.8000   37.70000      5.7750    64.91875
#
#      cross  cut-back  switch  shot_assist  goal_assist    play_pattern  \
# 0    False     False   False        False        False   From Kick Off
# 1    False     False   False        False        False   From Kick Off
# 3    False     False   False        False        False   From Throw In
# 5    False     False   False        False        False   From Throw In
# 6    False     False   False        False        False   From Throw In
# ..     ...       ...     ...          ...          ...             ...
# 909  False     False   False         True        False    Regular Play
# 918  False     False   False        False        False  From Free Kick
# 949  False     False   False        False        False  From Goal Kick
# 950  False     False   False        False        False  From Goal Kick
# 978  False     False   False        False        False  From Free Kick
#
#                                         related_events  \
# 0               [b7e37843-7498-42db-b117-ad4d40e0ed8c]
# 1               [916f2f17-c7ba-44b0-bce6-711b100f6d29]
# 3    [88a6c333-6ec0-4019-98c7-d1109c3c14ef, 9c31f4d...
# 5               [9bc9a6f7-86bd-4a8c-80f6-c530fe42df8f]
# 6               [8ac43856-0fbb-4f9e-a341-52c9486e2eae]
# ..                                                 ...
# 909             [bd174294-1a68-430e-bdf0-900a20646798]
# 918  [2aec1458-bbd3-4b62-a537-432d9f44fdae, e9c77f4...
# 949             [6b111a7a-87d5-4aa7-af2a-27ce2b925400]
# 950  [8e533d9c-46a4-4ba2-8c03-aee95e49e9cc, b54d630...
# 978                                                NaN
#
#                            recipient
# 0                         Ben Davies
# 1                              False
# 3    Kieffer Roberto Francisco Moore
# 5                       Aaron Ramsey
# 6                         Ben Davies
# ..                               ...
# 909  Kieffer Roberto Francisco Moore
# 918                  Brennan Johnson
# 949  Kieffer Roberto Francisco Moore
# 950                  Brennan Johnson
# 978                            False
#
# [351 rows x 19 columns]

# %%
passdata.pass_network(data=pW, pitch_col='#96b279')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  {'Aaron Ramsey': {'x_avg': 56.52791666666667,
#    'y_avg': 32.995625000000004,
#    'n': 30,
#    'n_complete': 24,
#    'receivers': {'Ben Davies': 5,
#     'Joe Rodon': 6,
#     'Neco Williams': 1,
#     'Ethan Ampadu': 3,
#     'Kieffer Roberto Francisco Moore': 2,
#     'Joe Allen': 2,
#     'Daniel James': 2,
#     'Chris Mepham': 2}},
#   'Ben Davies': {'x_avg': 40.48534482758621,
#    'y_avg': 57.525,
#    'n': 29,
#    'n_complete': 15,
#    'receivers': {'Kieffer Roberto Francisco Moore': 9,
#     'Aaron Ramsey': 6,
#     'Danny Ward': 1,
#     'Daniel James': 5,
#     'Ethan Ampadu': 4,
#     'Joe Rodon': 2}},
#   'Joe Rodon': {'x_avg': 30.782880434782616,
#    'y_avg': 38.275815217391305,
#    'n': 46,
#    'n_complete': 42,
#    'receivers': {'Ethan Ampadu': 3,
#     'Ben Davies': 7,
#     'Aaron Ramsey': 3,
#     'Daniel James': 3,
#     'Joe Allen': 4,
#     'Chris Mepham': 10,
#     'Danny Ward': 4}},
#   'Ethan Ampadu': {'x_avg': 49.76250000000001,
#    'y_avg': 24.885714285714286,
#    'n': 35,
#    'n_complete': 27,
#    'receivers': {'Chris Mepham': 10,
#     'Joe Rodon': 3,
#     'Kieffer Roberto Francisco Moore': 8,
#     'Daniel James': 2,
#     'Gareth Frank Bale': 1,
#     'Danny Ward': 1,
#     'Joe Allen': 4,
#     'Ben Davies': 1,
#     'Aaron Ramsey': 2}},
#   'Chris Mepham': {'x_avg': 35.156839622641506,
#    'y_avg': 16.68384433962264,
#    'n': 53,
#    'n_complete': 48,
#    'receivers': {'Danny Ward': 6,
#     'Joe Allen': 9,
#     'Neco Williams': 2,
#     'Gareth Frank Bale': 2,
#     'Kieffer Roberto Francisco Moore': 4,
#     'Ben Davies': 1,
#     'Aaron Ramsey': 3,
#     'Ethan Ampadu': 7,
#     'Joe Rodon': 8}},
#   'Danny Ward': {'x_avg': 10.48359375,
#    'y_avg': 33.9625,
#    'n': 32,
#    'n_complete': 20,
#    'receivers': {'Ben Davies': 2,
#     'Kieffer Roberto Francisco Moore': 8,
#     'Neco Williams': 1,
#     'Joe Allen': 1,
#     'Gareth Frank Bale': 2,
#     'Joe Rodon': 4,
#     'Ethan Ampadu': 1,
#     'Chris Mepham': 4,
#     'Daniel James': 1,
#     'Aaron Ramsey': 1}},
#   'Neco Williams': {'x_avg': 39.69583333333333,
#    'y_avg': 4.55,
#    'n': 6,
#    'n_complete': 5,
#    'receivers': {'Gareth Frank Bale': 1,
#     'Aaron Ramsey': 1,
#     'Ethan Ampadu': 1,
#     'Joe Allen': 1,
#     'Kieffer Roberto Francisco Moore': 1}},
#   'Gareth Frank Bale': {'x_avg': 37.082499999999996,
#    'y_avg': 21.076249999999998,
#    'n': 5,
#    'n_complete': 1,
#    'receivers': {'Neco Williams': 1,
#     'Aaron Ramsey': 1,
#     'Kieffer Roberto Francisco Moore': 1,
#     'Ben Davies': 1}},
#   'Joe Allen': {'x_avg': 47.920833333333334,
#    'y_avg': 26.309953703703712,
#    'n': 27,
#    'n_complete': 23,
#    'receivers': {'Aaron Ramsey': 5,
#     'Joe Rodon': 4,
#     'Ethan Ampadu': 3,
#     'Kieffer Roberto Francisco Moore': 2,
#     'Chris Mepham': 4,
#     'Ben Davies': 1,
#     'Daniel James': 1}},
#   'Kieffer Roberto Francisco Moore': {'x_avg': 67.06617647058823,
#    'y_avg': 49.20404411764705,
#    'n': 17,
#    'n_complete': 11,
#    'receivers': {'Gareth Frank Bale': 1,
#     'Daniel James': 3,
#     'Aaron Ramsey': 4,
#     'Ethan Ampadu': 1,
#     'Chris Mepham': 1,
#     'Joe Rodon': 1}},
#   'Daniel James': {'x_avg': 66.84416666666667,
#    'y_avg': 57.69833333333333,
#    'n': 15,
#    'n_complete': 10,
#    'receivers': {'Chris Mepham': 2,
#     'Kieffer Roberto Francisco Moore': 1,
#     'Ben Davies': 1,
#     'Aaron Ramsey': 4,
#     'Joe Allen': 3}}})

# %%
passdata = pass_data(df, data_source='Statsbomb', mirror_away=[''], scale_to_pitch='mplsoccer',
                    x_range_pitch=(0, 105), y_range_pitch=(0,68))
# Out:
# WARNING:root:mplsoccer pitch does not allow for a rescaling of the pitch. Axis ranges remain as(0, 120) for x and (80, 0) for y!
